# %%
import pandas as pd 
df=pd.read_csv('data.csv')
df.head()
# Out:
#    Unnamed: 0  Year        Country  Spending_USD  Life_Expectancy
# 0           0  1970        Germany       252.311             70.6
# 1           1  1970         France       192.143             72.2
# 2           2  1970  Great Britain       123.993             71.9
# 3           3  1970          Japan       150.437             72.0
# 4           4  1970            USA       326.961             70.9

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# Year                 int64
# Country             object
# Spending_USD       float64
# Life_Expectancy    float64
# dtype: object

# %%
df["Country"].value_counts()
# Out:
# Country
# USA              51
# Japan            51
# Germany          50
# Canada           44
# Great Britain    43
# France           35
# Name: count, dtype: int64

# %%
df["Country"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
df["Spending_USD"].describe()
# Out:
# count      274.000000
# mean      2789.338905
# std       2194.939785
# min        123.993000
# 25%       1038.357000
# 50%       2295.578000
# 75%       4055.610000
# max      11859.179000
# Name: Spending_USD, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['Spending_USD'], kde=True)
plt.show()

sns.boxplot(x=df['Spending_USD'])
plt.show()

# %%
df["Life_Expectancy"].describe()
# Out:
# count    274.000000
# mean      77.909489
# std        3.276263
# min       70.600000
# 25%       75.525000
# 50%       78.100000
# 75%       80.575000
# max       84.700000
# Name: Life_Expectancy, dtype: float64

# %%
sns.histplot(df["Life_Expectancy"], kde=True)
plt.show()

sns.boxplot(x=df["Life_Expectancy"])
plt.show()

# %%
sns.lineplot(data=df, x="Year", y="Life_Expectancy", hue="Country")
plt.show()

# %%
# Filtrage
comparison_df = df[df['Country'].isin(['Germany', 'Great Britain'])] # Adapte selon les noms exacts

sns.lineplot(data=comparison_df, x='Year', y='Spending_USD', hue='Country')
# Out:
# <Axes: xlabel='Year', ylabel='Spending_USD'>

# %%
# df.groupby('Country')['Spending_USD'].mean().plot(kind='bar')
# sns.boxplot(x='Country', y='Spending_USD', data=df) 
# sns.scatterplot(data=df, x='Spending_USD', y='Country')
sns.distplot(x='Country',data=df,y='Spending_USD')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 4
#       1 # df.groupby('Country')['Spending_USD'].mean().plot(kind='bar')
#       2 # sns.boxplot(x='Country', y='Spending_USD', data=df)
#       3 # sns.scatterplot(data=df, x='Spending_USD', y='Country')
# ----> 4 sns.distplot(x='Country',y='Spending_USD')
#
# TypeError: distplot() got an unexpected keyword argument 'y'
